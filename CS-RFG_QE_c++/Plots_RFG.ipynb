# %%
dataRFG1=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/Ei961_th37.out",header=FALSE)
dataRFG2=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/Ei1000_C/Ei1000_th45.out",header=FALSE)

names(dataRFG1)=c("omega","kf","d3sig")
names(dataRFG2)=c("omega","kf","d3sig")

# %%
fixlooks=function(k,sigma){
  l=length(k)
  if(k[1]>k[l]){
    extend=seq(min(k),0)
    ktot=c(k,extend)
    stot=c(sigma,numeric(length(extend)))
    return(cbind(ktot,stot))
  }else{
    extend=seq(0,min(k))
    ktot=c(extend,k)
    stot=c(numeric(length(extend)),sigma)
    return(cbind(ktot,stot))
  }
}

# %%
par(mfrow=c(1,2))


vals=fixlooks(dataRFG1$kf,dataRFG1$d3sig)

kftot=vals[,1]
stot=vals[,2]



plot(kftot/1000,stot,
     xlab="$k_{f}\\;(GeV)$",
     ylab="$d^{3}\\sigma/dk_{f}\\,d\\Omega_{f}\\;\\;(fm^{2}\\cdot MeV^{-1}\\cdot sr^{-1})$",
     cex.lab=0.75,cex.axis=0.75,
     type="l",
     col="hotpink3")

vals=fixlooks(dataRFG2$kf,dataRFG2$d3sig)

kftot=vals[,1]
stot=vals[,2]



plot(kftot/1000,stot,
     xlab="$k_{f}\\;(GeV)$",
     ylab="$d^{3}\\sigma/dk_{f}\\,d\\Omega_{f}\\;\\;(fm^{2}\\cdot MeV^{-1}\\cdot sr^{-1})$",
     cex.lab=0.75,cex.axis=0.75,
     type="l",
     col="darkorchid")
# Out:
# plot without title

# %%
data1000=read.table("/Users/mcytron/TFG-CODE/lepton-nucleon-c++/Ei1000.out",header=FALSE)
names(data1000)=c("omega","K_f","P_n","Q2","dsigQ2","costheta_f","dsig")

# %%
deg=acos(data1000$costheta_f)*180/pi
good=deg<=90

plot(deg[good],data1000$dsig[good],
     xlab="\\theta\\;(deg)",
     ylab=" ",
     cex.lab=0.75,cex.axis=0.75,
     type="l",
     col="royalblue")

n_vals=seq(1,10,1)
data=list()
d2sig=numeric(length(n_vals))
i=1

for (n in n_vals) {#CARBON
    # Construct the file name
    fn=paste0("/Users/mcytron/TFG-CODE/RFG_QE_c++/Ei1000_C/Ei1000_th", n, ".out")
    
    # Read the data from the file (adjust the path as needed)
    data[[n]]=read.table(fn, header = FALSE)
    u=data[[n]]
    names(u)=c("omega","kf","d3sig")
    d2sig[i]=sum(u$d3sig)*2*pi/6
    i=i+1
}

lines(n_vals,d2sig,col="hotpink3")

n_vals=seq(10,90,5)
data=list()
d2sig=numeric(length(n_vals))
i=1

for (n in n_vals) {#CARBON
    # Construct the file name
    fn=paste0("/Users/mcytron/TFG-CODE/RFG_QE_c++/Ei1000_C/Ei1000_th", n, ".out")
    
    # Read the data from the file (adjust the path as needed)
    data[[n]]=read.table(fn, header = FALSE)
    u=data[[n]]
    names(u)=c("omega","kf","d3sig")
    d2sig[i]=sum(u$d3sig)*2*pi/6
    i=i+1
}

lines(n_vals,d2sig,col="hotpink3")

n_vals=seq(15,90,5)
data=list()
d2sig=numeric(length(n_vals))
i=1

for (n in n_vals) {#DEUTERIUM
    # Construct the file name
    fn=paste0("/Users/mcytron/TFG-CODE/RFG_QE_c++/Ei1000_D/Ei1000_th", n, ".out")
    
    # Read the data from the file (adjust the path as needed)
    data[[n]]=read.table(fn, header = FALSE)
    u=data[[n]]
    names(u)=c("omega","kf","d3sig")
    d2sig[i]=sum(u$d3sig)*2*pi
    i=i+1
}

lines(n_vals,d2sig,col="firebrick3")

n_vals=seq(1,15,1)
data=list()
d2sig=numeric(length(n_vals))
i=1

for (n in n_vals) {#DEUTERIUM
    # Construct the file name
    fn=paste0("/Users/mcytron/TFG-CODE/RFG_QE_c++/Ei1000_D/Ei1000_th", n, ".out")
    
    # Read the data from the file (adjust the path as needed)
    data[[n]]=read.table(fn, header = FALSE)
    u=data[[n]]
    names(u)=c("omega","kf","d3sig")
    d2sig[i]=sum(u$d3sig)*2*pi
    i=i+1
}

lines(n_vals,d2sig,col="firebrick3")


n_vals=seq(5,90,5)
data=list()
d2sig=numeric(length(n_vals))
i=1

for (n in n_vals) {#IRON
    # Construct the file name
    fn=paste0("/Users/mcytron/TFG-CODE/RFG_QE_c++/Ei1000_Fe/Ei1000_th", n, ".out")
    
    # Read the data from the file (adjust the path as needed)
    data[[n]]=read.table(fn, header = FALSE)
    u=data[[n]]
    names(u)=c("omega","kf","d3sig")
    d2sig[i]=sum(u$d3sig)*2*pi/30
    i=i+1
}

lines(n_vals,d2sig,col="coral1")

n_vals=seq(1,5,1)
data=list()
d2sig=numeric(length(n_vals))
i=1

for (n in n_vals) {#IRON
    # Construct the file name
    fn=paste0("/Users/mcytron/TFG-CODE/RFG_QE_c++/Ei1000_Fe/Ei1000_th", n, ".out")
    
    # Read the data from the file (adjust the path as needed)
    data[[n]]=read.table(fn, header = FALSE)
    u=data[[n]]
    names(u)=c("omega","kf","d3sig")
    d2sig[i]=sum(u$d3sig)*2*pi/30
    i=i+1
}

lines(n_vals,d2sig,col="coral1")


n_vals=seq(10,90,5)
data=list()
d2sig=numeric(length(n_vals))
i=1

for (n in n_vals) {#ARGON
    # Construct the file name
    fn=paste0("/Users/mcytron/TFG-CODE/RFG_QE_c++/Ei1000_Ar/Ei1000_th", n, ".out")
    
    # Read the data from the file (adjust the path as needed)
    data[[n]]=read.table(fn, header = FALSE)
    u=data[[n]]
    names(u)=c("omega","kf","d3sig")
    d2sig[i]=sum(u$d3sig)*2*pi/22
    i=i+1
}

lines(n_vals,d2sig,col="darkolivegreen")

n_vals=seq(1,10,1)
data=list()
d2sig=numeric(length(n_vals))
i=1

for (n in n_vals) {#ARGON
    # Construct the file name
    fn=paste0("/Users/mcytron/TFG-CODE/RFG_QE_c++/Ei1000_Ar/Ei1000_th", n, ".out")
    
    # Read the data from the file (adjust the path as needed)
    data[[n]]=read.table(fn, header = FALSE)
    u=data[[n]]
    names(u)=c("omega","kf","d3sig")
    d2sig[i]=sum(u$d3sig)*2*pi/22
    i=i+1
}

lines(n_vals,d2sig,col="darkolivegreen")

legend(x="topright",
       legend=c("Dispersión elástica","QE RFG 12C","QE RFG 2H","QE RFG 56Fe","QE CC 40Ar"),
       col=c("royalblue","hotpink3","firebrick3","coral1","darkolivegreen"),lty=c("solid","solid","solid","solid","solid"),cex=0.6)

mtext("$d\\sigma/d\\cos(\\theta)\\;\\;(fm^{2})$",side=2,line=2,cex=0.75)
mtext("$Sección\\;eficaz\\;diferencial\\;del\\;proceso\\;\\nu_{\\mu}+n\\to\\mu^{-}+p",side=3,las=1,line=0.8,cex=1)
# Out:
# plot without title

# %%
n_vals=seq(5,90,5)
data=list()
d2sig=numeric(length(n_vals))
i=1

for (n in n_vals) {
    # Construct the file name
    fn=paste0("/Users/mcytron/TFG-CODE/RFG_QE_c++/Ei1000_D/Ei1000_th", n, ".out")
    
    # Read the data from the file (adjust the path as needed)
    data[[n]]=read.table(fn, header = FALSE)
    u=data[[n]]
    names(u)=c("omega","kf","d3sig")
    d2sig[i]=sum(u$d3sig)*2*pi
    i=i+1
}

# %%
d2sig[1]
# Out:
# [1] 2.165311e-12

# %%
deg=acos(data1000$costheta_f)*180/pi
good=deg<=90

plot(deg[good],data1000$dsig[good],
     col="royalblue",
    xlab="\\theta\\;(deg)",
     ylab=" ",
     cex.lab=0.75,cex.axis=0.75,
     type="l")

points(n_vals,d2sig,col="hotpink3")



legend(x="topright",
       legend=c("Dispersión elástica","QE RFG 2H"),
       col=c("royalblue","hotpink3"),lty=c("solid","solid"),cex=0.6)

mtext("$d\\sigma/d\\cos(\\theta)\\;\\;(fm^{2})$",side=2,line=2,cex=0.75)
mtext("$Sección\\;eficaz\\;diferencial\\;del\\;proceso\\;\\nu_{\\mu}+n\\to\\mu^{-}+p",side=3,las=1,line=0.8,cex=1)
# Out:
# plot without title

# %%
plot(deg[good],data1000$dsig[good],
     xlab="\\theta\\;(deg)",
     ylab=" ",
     cex.lab=0.75,cex.axis=0.75,
     type="l",
     col="royalblue")



n_vals=seq(5,90,5)
data=list()
d2sig=numeric(length(n_vals))
i=1

for (n in n_vals) {
    # Construct the file name
    fn=paste0("/Users/mcytron/TFG-CODE/RFG_QE_c++/Ei1000_Fe/Ei1000_th", n, ".out")
    
    # Read the data from the file (adjust the path as needed)
    data[[n]]=read.table(fn, header = FALSE)
    u=data[[n]]
    names(u)=c("omega","kf","d3sig")
    d2sig[i]=sum(u$d3sig)*2*pi/30
    i=i+1
}

lines(n_vals,d2sig,col="coral1")

n_vals=seq(1,5,1)
data=list()
d2sig=numeric(length(n_vals))
i=1

for (n in n_vals) {
    # Construct the file name
    fn=paste0("/Users/mcytron/TFG-CODE/RFG_QE_c++/Ei1000_Fe/Ei1000_th", n, ".out")
    
    # Read the data from the file (adjust the path as needed)
    data[[n]]=read.table(fn, header = FALSE)
    u=data[[n]]
    names(u)=c("omega","kf","d3sig")
    d2sig[i]=sum(u$d3sig)*2*pi/30
    i=i+1
}

lines(n_vals,d2sig,col="coral1")


deg=acos(data1000$costheta_f)*180/pi
good=deg<=90
# Out:
# plot without title
