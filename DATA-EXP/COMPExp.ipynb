# %%
#nd280data-numu-cc0pi-xs-on-c-2015

rm=function(a){return(a<0.5)}



data1=read.table("/Users/mcytron/TFG-CODE/DATA-EXP/cross-section_analysisI.txt",header=TRUE)
data2=read.table("/Users/mcytron/TFG-CODE/DATA-EXP/rps_crossSection_analysis2.txt",header=TRUE)

data1=cbind(data1,apply(cbind(data1[,2],data1[,3]),1,mean),apply(cbind(data1[,4],data1[,5]),1,mean))
data2=cbind(data2,apply(cbind(data2[,2],data2[,3]),1,mean),apply(cbind(data2[,4],data2[,5]),1,mean))

names(data1)[7:8]=c("costheta","p")
names(data2)[7:8]=c("costheta","p")

# %%
c1=data1$costheta
cmin1=data1$cosThetamin
cmax1=data1$cosThetamax

x1=data1$xsec

p1=data1$p
pmin1=data1$momentummin
pmax1=data1$momentummax

# %%
c2=data2$costheta
cmin2=data2$cosThetamin
cmax2=data2$cosThetamax

x2=data2$xsec

p2=data2$p
pmin2=data2$momentummin
pmax2=data2$momentummax

# %%
#costheta     avg    thetaWRONG   theta   thetamin-thetamax

#(-1  0)     -0.5    120         
#(0  0.6)     0.3    72.54
#(0.6  0.7)   0.5    60           49.35   53.13(DONE)-45.57
#(0.7  0.8)   0.6    53.13        41.41   45.57(DONE)-36.87
#(0.8  0.85)  0.825  34.41        good    36.87(DONE)-31.79
#(0.85  0.9)  0.875  28.96        good    31.79(DONE)-25.84
#(0.9  0.94)  0.92   23.07        good    25.84(DONE)-19.95
#(0.94  0.98) 0.96   16.26        good    19.95(DONE)-11.48
#(0.98  1)    0.99   8.11         good    11.48(DONE)-0

# %%
err11=read.table("/Users/mcytron/TFG-CODE/DATA-EXP/covariance_fluxNormalizationSystematics_analysisI.txt",header=TRUE)
err11.f=factor(err11$i)
err11=tapply(err11$cov,err11.f,sum)
# err11=err11$cov[err11$i==err11$j]

err12=read.table("/Users/mcytron/TFG-CODE/DATA-EXP/covariance_shapeSystematics_analysisI.txt",header=TRUE)
err12.f=factor(err12$i)
err12=tapply(err12$cov,err12.f,sum)
# err12=err12$cov[err12$i==err12$j]

err13=read.table("/Users/mcytron/TFG-CODE/DATA-EXP/covariance_statisticUncertainty_analysisI.txt",header=TRUE)
err13.f=factor(err13$i)
err13=tapply(err13$cov,err13.f,sum)
# err13=err13$cov[err13$i==err13$j]

err1=err11+err12+err13

# %%
par(mfrow=c(3,3))

# #1)

# dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th120.out",header=FALSE)
# names(dataC)=c("kf","kfp","d3sig")
# min=-1
# max=0
# u=(cmax1==max&cmin1==min)
# kf=dataC$kfp/1000

# plot(kf,dataC$d3sig/10,type="l",lty=3,main="-1<=costheta<=0",
#      xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
# points(p1,x1,col="hotpink3",pch=20,cex=0.5)

# arrows(pmin1[u], x1[u], pmax1[u], x1[u], code=3,angle=90, length=0.02, col="hotpink3")
# #arrows(p1[u],xmin1[u] ,p1[u],xmax1[u], code=3,angle=90, length=0.02, col="hotpink3")

#2)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th72.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0
max=0.6
u=(cmax1==max&cmin1==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0<=costheta<=0.6",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p1[u],x1[u],col="hotpink3",pch=20,cex=0.5)

arrows(pmin1[u], x1[u], pmax1[u], x1[u], code=3,angle=90, length=0.02, col="hotpink3")
arrows(p1[u],x1[u]-err1[u],p1[u],x1[u]+err1[u], code=3,angle=90, length=0.02, col="hotpink3")

#3)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th60.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.6
max=0.7
u=(cmax1==max&cmin1==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.6<=costheta<=0.7",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p1[u],x1[u],col="hotpink3",pch=20,cex=0.5)

arrows(pmin1[u], x1[u], pmax1[u], x1[u], code=3,angle=90, length=0.02, col="hotpink3")
arrows(p1[u],x1[u]-err1[u],p1[u],x1[u]+err1[u], code=3,angle=90, length=0.02, col="hotpink3")

#4)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th53.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.7
max=0.8
u=(cmax1==max&cmin1==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.7<=costheta<=0.8",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p1[u],x1[u],col="hotpink3",pch=20,cex=0.5)

arrows(pmin1[u], x1[u], pmax1[u], x1[u], code=3,angle=90, length=0.02, col="hotpink3")
arrows(p1[u],x1[u]-err1[u],p1[u],x1[u]+err1[u], code=3,angle=90, length=0.02, col="hotpink3")

#5)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th34.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.8
max=0.85
u=(cmax1==max&cmin1==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.8<=costheta<=0.85",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p1[u],x1[u],col="hotpink3",pch=20,cex=0.5)

arrows(pmin1[u], x1[u], pmax1[u], x1[u], code=3,angle=90, length=0.02, col="hotpink3")
arrows(p1[u],x1[u]-err1[u],p1[u],x1[u]+err1[u], code=3,angle=90, length=0.02, col="hotpink3")

#6)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th28.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.85
max=0.9
u=(cmax1==max&cmin1==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.85<=costheta<=0.9",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p1[u],x1[u],col="hotpink3",pch=20,cex=0.5)

arrows(pmin1[u], x1[u], pmax1[u], x1[u], code=3,angle=90, length=0.02, col="hotpink3")
arrows(p1[u],x1[u]-err1[u],p1[u],x1[u]+err1[u], code=3,angle=90, length=0.02, col="hotpink3")

#7)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th23.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.9  
max=0.94
u=(cmax1==max&cmin1==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.9<=costheta<=0.94",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p1[u],x1[u],col="hotpink3",pch=20,cex=0.5)

arrows(pmin1[u], x1[u], pmax1[u], x1[u], code=3,angle=90, length=0.02, col="hotpink3")
arrows(p1[u],x1[u]-err1[u],p1[u],x1[u]+err1[u], code=3,angle=90, length=0.02, col="hotpink3")

#8)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th16.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.94  
max=0.98
u=(cmax1==max&cmin1==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.94<=costheta<=0.98",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p1[u],x1[u],col="hotpink3",pch=20,cex=0.5)

arrows(pmin1[u], x1[u], pmax1[u], x1[u], code=3,angle=90, length=0.02, col="hotpink3")
arrows(p1[u],x1[u]-err1[u],p1[u],x1[u]+err1[u], code=3,angle=90, length=0.02, col="hotpink3")

#8)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th8.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.98 
max=1
u=(cmax1==max&cmin1==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.98<=costheta<=1",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p1[u],x1[u],col="hotpink3",pch=20,cex=0.5)

arrows(pmin1[u], x1[u], pmax1[u], x1[u], code=3,angle=90, length=0.02, col="hotpink3")
arrows(p1[u],x1[u]-err1[u],p1[u],x1[u]+err1[u], code=3,angle=90, length=0.02, col="hotpink3")
# Out:
# Warning message in arrows(p1[u], x1[u] - err1[u], p1[u], x1[u] + err1[u], code = 3, :
# “zero-length arrow is of indeterminate angle and so skipped”Warning message in arrows(p1[u], x1[u] - err1[u], p1[u], x1[u] + err1[u], code = 3, :
# “zero-length arrow is of indeterminate angle and so skipped”Warning message in arrows(p1[u], x1[u] - err1[u], p1[u], x1[u] + err1[u], code = 3, :
# “zero-length arrow is of indeterminate angle and so skipped”
# Plot with title “0.98<=costheta<=1”

# %%
#costheta      avg    theta

#(0.6  0.7)    0.5     60  DONE
#(0.7  0.8)    0.75    41.41 DONE
#(0.8  0.85)   0.825   34.41 DONE
#(0.85  0.9)   0.875   28.96 DONE
#(0.9  0.925)  0.9125  24.15
#(0.925  0.95) 0.9375  20.36
#(0.95  0.975) 0.9625  15.74
#(0.975  1.0)  0.9875  9.07

# %%
err21=read.table("/Users/mcytron/TFG-CODE/DATA-EXP/rps_fluxNormCov_analysis2.txt",header=TRUE)
err21.f=factor(err21$i)
err21=tapply(err21$cov,err21.f,sum)
#err21=err21$cov[err21$i==err21$j]

err22=read.table("/Users/mcytron/TFG-CODE/DATA-EXP/rps_statsCov_analysis2.txt",header=TRUE)
err22.f=factor(err22$i)
err22=tapply(err22$cov,err22.f,sum)
#err22=err22$cov[err22$i==err22$j]

err23=read.table("/Users/mcytron/TFG-CODE/DATA-EXP/rps_systCov_analysis2.txt",header=TRUE)
err23.f=factor(err23$i)
err23=tapply(err23$cov,err23.f,sum)
#err23=err23$cov[err23$i==err23$j]

err2=err21+err22+err23

#err2=err21

# %%
par(mfrow=c(3,3))

# #1)

# dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th60.out",header=FALSE)
# names(dataC)=c("kf","kfp","d3sig")
# min=0.6
# max=0.7
# u=(cmax2==max&cmin2==min)
# kf=dataC$kfp/1000

# plot(kf,dataC$d3sig/10,type="l",lty=3,main="0.6<=costheta<=0.7",
#      xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
# points(p2,x2,col="royalblue3",pch=20,cex=0.5)

# arrows(pmin2[u], x2[u], pmax2[u], x2[u], code=3,angle=90, length=0.02, col="royalblue3")
# #arrows(p2[u],xmin2[u] ,p2[u],xmax2[u], code=3,angle=90, length=0.02, col="royalblue3")

#2)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th41.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.7
max=0.8
u=(cmax2==max&cmin2==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.7<=costheta<=0.8",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p2[u],x2[u],col="royalblue3",pch=20,cex=0.5,main="0<=costheta<=0.6",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)")

arrows(pmin2[u], x2[u], pmax2[u], x2[u], code=3,angle=90, length=0.02, col="royalblue3")
arrows(p2[u],x2[u]-err2[u] ,p2[u],x2[u]+err2[u], code=3,angle=90, length=0.02, col="royalblue3")

#3)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th34.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.8
max=0.85
u=(cmax2==max&cmin2==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.8<=costheta<=0.85",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p2[u],x2[u],col="royalblue3",pch=20,cex=0.5)

arrows(pmin2[u], x2[u], pmax2[u], x2[u], code=3,angle=90, length=0.02, col="royalblue3")
arrows(p2[u],x2[u]-err2[u] ,p2[u],x2[u]+err2[u], code=3,angle=90, length=0.02, col="royalblue3")

#4)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th28.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.85
max=0.9
u=(cmax2==max&cmin2==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.85<=costheta<=0.9",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p2[u],x2[u],col="royalblue3",pch=20,cex=0.5)

arrows(pmin2[u], x2[u], pmax2[u], x2[u], code=3,angle=90, length=0.02, col="royalblue3")
arrows(p2[u],x2[u]-err2[u] ,p2[u],x2[u]+err2[u], code=3,angle=90, length=0.02, col="royalblue3")

#5)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th24.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.9  
max=0.925
u=(cmax2==max&cmin2==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.9<=costheta<=0.925",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p2[u],x2[u],col="royalblue3",pch=20,cex=0.5)

arrows(pmin2[u], x2[u], pmax2[u], x2[u], code=3,angle=90, length=0.02, col="royalblue3")
arrows(p2[u],x2[u]-err2[u] ,p2[u],x2[u]+err2[u], code=3,angle=90, length=0.02, col="royalblue3")

#6)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th20.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.925
max=0.95
u=(cmax2==max&cmin2==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.925<=costheta<=0.95",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p2[u],x2[u],col="royalblue3",pch=20,cex=0.5)

arrows(pmin2[u], x2[u], pmax2[u], x2[u], code=3,angle=90, length=0.02, col="royalblue3")
arrows(p2[u],x2[u]-err2[u] ,p2[u],x2[u]+err2[u], code=3,angle=90, length=0.02, col="royalblue3")

#7)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th15.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.95
max=0.975
u=(cmax2==max&cmin2==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.95<=costheta<=0.975",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p2[u],x2[u],col="royalblue3",pch=20,cex=0.5)

arrows(pmin2[u], x2[u], pmax2[u], x2[u], code=3,angle=90, length=0.02, col="royalblue3")
arrows(p2[u],x2[u]-err2[u] ,p2[u],x2[u]+err2[u], code=3,angle=90, length=0.02, col="royalblue3")

#8)

dataC=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/th9.out",header=FALSE)
names(dataC)=c("kf","kfp","d3sig")
min=0.975
max=1
u=(cmax2==max&cmin2==min)
kf=dataC$kfp/1000

plot(kf,dataC$d3sig/10,type="l",lty="dotted",main="0.975<=costheta<=1",
    xlab="kf (GeV)",ylab="ds/dkfdcostheta (10^-38 cm^2/GeV/Nucleon)") #10-39cm^2 ->10-38 cm^2
points(p2[u],x2[u],col="royalblue3",pch=20,cex=0.5)

arrows(pmin2[u], x2[u], pmax2[u], x2[u], code=3,angle=90, length=0.02, col="royalblue3")
arrows(p2[u],x2[u]-err2[u] ,p2[u],x2[u]+err2[u], code=3,angle=90, length=0.02, col="royalblue3")
# Out:
# Warning message in arrows(p2[u], x2[u] - err2[u], p2[u], x2[u] + err2[u], code = 3, :
# “zero-length arrow is of indeterminate angle and so skipped”Warning message in arrows(p2[u], x2[u] - err2[u], p2[u], x2[u] + err2[u], code = 3, :
# “zero-length arrow is of indeterminate angle and so skipped”Warning message in arrows(p2[u], x2[u] - err2[u], p2[u], x2[u] + err2[u], code = 3, :
# “zero-length arrow is of indeterminate angle and so skipped”Warning message in arrows(p2[u], x2[u] - err2[u], p2[u], x2[u] + err2[u], code = 3, :
# “zero-length arrow is of indeterminate angle and so skipped”Warning message in arrows(p2[u], x2[u] - err2[u], p2[u], x2[u] + err2[u], code = 3, :
# “zero-length arrow is of indeterminate angle and so skipped”Warning message in arrows(p2[u], x2[u] - err2[u], p2[u], x2[u] + err2[u], code = 3, :
# “zero-length arrow is of indeterminate angle and so skipped”Warning message in arrows(p2[u], x2[u] - err2[u], p2[u], x2[u] + err2[u], code = 3, :
# ...

# %%
dataE=read.table("/Users/mcytron/TFG-CODE/T2K-nd280-Edep-2014/enu_dependent_cross_section.csv",header=TRUE,sep=",")

# %%
dataE
# Out:
#   Enu     Enumin Enumax sigma   sigmamin sigmamax
# 1 0.43761 0.0     0.6   0.68491 0.57404  0.81794
# 2 0.64820 0.6     0.7   0.77150 0.58179  0.97860
# 3 0.80910 0.7     1.0   1.08959 0.89741  1.32840
# 4 1.19633 1.0     1.5   0.36890 0.03973  0.71672
# 5 3.37397 1.5    30.0   1.37898 0.97709  1.81740

# %%
plot(dataE$Enu,dataE$sigma)
errs=(dataE$sigmamax-dataE$sigmamin)/2
errE=(dataE$Enumax-dataE$Enumin)/2

arrows(dataE$Enu,dataE$sigma-errs,dataE$Enu,dataE$sigma+errs,code=3,angle=90, length=0.02, col="royalblue")
arrows(dataE$Enu-errE,dataE$sigma,dataE$Enu+errE,dataE$sigma,code=3,angle=90, length=0.02, col="royalblue")
# Out:
# plot without title

# %%
# err1p=abs(data1$momentummin-data1$momentummax)/2
# err1x=abs((data1$cosThetamin-data1$cosThetamax)/2)*x1/data1$costheta
# a=rm(err1p)&rm(err1x)

# p1=p1[a]
# x1=x1[a]

# err1p=err1p[a]
# err1x=err1x[a]
# costheta1=costheta1[a]

#steps: 
#0.63  (0.5-0.65)   50.95
#0.79  (0.75-0.825) 37.81
#0.896 (0.875-0.92) 26.36
#0.972 (0.96-0.99)  13.59

# %%
# p2=p2[b]
# x2=x2[b]
# costheta2=costheta2[b]

# err2p=err2p[b]
# err2x=err2x[b]

# #steps
# #0.7   (0.65-0.75)     45.57
# #0.85  (0.825-0.875)   31.79
# #0.925 (0.9125-0.9375) 22.33
# #0.975 (0.9625-0.9875) 12.84

# #0.95 (0.9125-0.9875) 18.19

# %%
# err2p=abs(data2$momentummin-data2$momentummax)/2
# err2x=abs((data2$cosThetamin-data2$cosThetamax)/2)*x2/data2$costheta
# b=rm(err2p)&rm(err2x)

# %%
flux=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/t2kflux_numu_2016.dat",header=FALSE)
names(flux)=c("enu","flux")

# %%
plot(flux$enu,flux$flux,type="l",lty="dotted",
    xlab="Enu",ylab="flux(enu)")
# Out:
# plot without title
