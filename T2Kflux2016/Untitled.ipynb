# %%
data_plus=read.table("/Users/mcytron/TFG-CODE/T2Kflux2016/t2kflux_2016_sk_plus250kA.txt",header=TRUE,sep="")
data_minus=read.table("/Users/mcytron/TFG-CODE/T2Kflux2016/t2kflux_2016_sk_minus250kA.txt",header=TRUE,sep="")

# %%
E=apply(cbind(data_plus$Emin,data_plus$Emax),1,mean)*1000;
sum(E==apply(cbind(data_minus$Emin,data_minus$Emax),1,mean)*1000)==length(E)
# Out:
# [1] TRUE

# %%
data_plus[1,]
val0=1.8389267e-05

c1=data_plus$numu[1]/val0;c1
c2=data_minus$numu[1]/val0

data_plus$numu[2]/c1
data_minus$numu[2]/c2
val1=7.4183976e-05;val1
val20=0.00031554311
data_plus$numu[20]/c1
data_minus$numu[20]/c2
# Out:
#   Bin Emin Emax numu  antinumu nue antinue
# 1 1   0    0.05 12700 16400    180 29.7
# [1] 690620241
# [1] 7.819058e-05
# [1] 5.952595e-05
# [1] 7.418398e-05
# [1] 0.0002012684
# [1] 2.508594e-05

# %%
norm_p=sum(data_plus$numu)

norm_m=sum(data_minus$numu)

data_plus$numu[4]/norm_p
data_minus$numu[4]/norm_m
# Out:
# [1] 0.01401263
# [1] 0.02931031

# %%
data=read.table("/Users/mcytron/TFG-CODE/RFG_QE_c++/con-flujo/t2kflux_numu_2016.dat",header=FALSE,sep="")

# %%
norm=sum(data$V2)

data$V2[4]/norm
# Out:
# [1] 0.01143568

# %%
datand280.1=read.table("/Users/mcytron/TFG-CODE/nd280data-numu-cc0pi-xs-on-c-2015/rps_crossSection_analysis2.txt",header=TRUE,sep="")
#nd280data-numu-cc0pi-xs-on-c-2015


datand280.1=cbind(datand280.1,apply(cbind(datand280.1$cosThetamin,datand280.1$cosThetamax),1,mean))
names(datand280.1)[7]="ctheta"
#datand280

# %%
plot(datand280.1$ctheta,datand280.1$xsec)
# Out:
# plot without title

# %%
datand280.2=read.table("/Users/mcytron/TFG-CODE/nd280data-numu-cc0pi-xs-on-c-2015/cross-section_analysisI.txt",header=TRUE,sep="")
#nd280data-numu-cc0pi-xs-on-c-2015


datand280.2=cbind(datand280.2,apply(cbind(datand280.2$cosThetamin,datand280.2$cosThetamax),1,mean))
names(datand280.2)[7]="ctheta"
#datand280
datand280.2$ctheta
# Out:
#  [1] 0.500 0.500 0.500 0.300 0.300 0.300 0.300 0.300 0.650 0.650 0.650 0.650
# [13] 0.650 0.650 0.650 0.750 0.750 0.750 0.750 0.750 0.750 0.750 0.825 0.825
# [25] 0.825 0.825 0.825 0.825 0.825 0.825 0.875 0.875 0.875 0.875 0.875 0.875
# [37] 0.875 0.875 0.875 0.920 0.920 0.920 0.920 0.920 0.920 0.920 0.920 0.960
# [49] 0.960 0.960 0.960 0.960 0.960 0.960 0.960 0.960 0.960 0.960 0.990 0.990
# [61] 0.990 0.990 0.990 0.990 0.990 0.990 0.990

# %%
plot(datand280.2$ctheta,datand280.2$xsec)
# Out:
# plot without title

# %%
ctheta=c(datand280.1$ctheta,datand280.2$ctheta);length(ctheta)
xsec=c(datand280.1$xsec,datand280.2$xsec);length(xsec)

plot(ctheta,xsec)
# Out:
# [1] 163
# [1] 163
# plot without title

# %%
67+96
# Out:
# [1] 163

# %%
length(datand280.1$xsec)
# Out:
# [1] 96

# %%
datand280.2$xsec
# Out:
#  [1] 0.255394000 0.207948000 0.000271813 0.208457000 0.724434000 0.551849000
#  [7] 0.234113000 0.000368685 0.178667000 0.638440000 0.714696000 0.935747000
# [13] 0.646835000 0.071504600 0.000476125 0.104217000 0.490643000 0.824596000
# [19] 0.915528000 0.775158000 0.255488000 0.002194110 0.130715000 0.494917000
# [25] 0.760770000 0.929140000 0.605259000 0.478013000 0.330544000 0.001706000
# [31] 0.051962300 0.383728000 0.743677000 0.863931000 1.028850000 0.465526000
# [37] 0.288899000 0.174840000 0.000506115 0.118570000 0.652239000 0.821718000
# [43] 0.474617000 0.584867000 0.351801000 0.113308000 0.001523860 0.097186900
# [49] 0.361972000 0.618293000 0.814948000 0.519460000 0.554242000 0.390123000
# [55] 0.258903000 0.310958000 0.115618000 0.003933590 0.130586000 0.225854000
# [61] 0.338863000 0.301963000 0.117946000 0.239808000 0.283177000 0.281044000
# [67] 0.012820400
